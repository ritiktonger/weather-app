# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import g_key

# %%
filepath=os.path.join("..","WeatherPy","Output","WeatherData_703_2020_0205.csv")
randomWeather=pd.read_csv(filepath)
randomWeather.head()
# Out:
#    Unnamed: 0       City      Lat       Lng  Temp_F  Humidity  Cloudiness  \
# 0           0    Tétange  49.4758    6.0422   42.64        93         100
# 1           1     Pansoy  13.1825  122.5989   80.96        77          60
# 2           2  Saraipali  21.3333   83.0000   85.46        16           0
# 3           3   Manosque  43.8288    5.7869   52.97        80         100
# 4           4    Mulgund  15.2500   75.5333   80.60        29           0
#
#    Windspeed
# 0       4.00
# 1       7.94
# 2       1.36
# 3       7.00
# 4       6.91
